# %%
import matplotlib.pyplot as plt

x = np.array([5, 3, 9, 2, 4, 1])
plt.plot(x);
plt.xticks(range(len(x)), ['a', 'b', 'c', 'd', 'e', 'f']); 
plt.yticks(range(1, 8, 2));
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-af415a63c40f> in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 x = np.array([5, 3, 9, 2, 4, 1])
#       4 plt.plot(x);
#       5 plt.xticks(range(len(x)), ['a', 'b', 'c', 'd', 'e', 'f']);
#
# NameError: name 'np' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.random.randn(100)
print(y)
plt.hist(y);
plt.show()
# Out:
# [ 0.40501347  0.0049877   0.68084796 -0.11853416 -0.49312674  0.94376797
#   1.08896971  0.04592819  0.11025919  1.73045654  0.48812452 -0.18216055
#  -0.07068449 -0.79633587 -1.69294669 -0.2993956   0.7036805  -1.66388559
#   0.38565851 -0.29614248 -0.94508036 -0.78448188 -0.86741944 -0.21103059
#  -1.27494636 -0.1962467   1.08385032  0.55642329 -0.22632761  0.43046449
#  -0.33444605 -1.02404506 -0.06323619 -1.1974995   0.16469276  1.21442115
#  -0.04758693 -0.49328799 -1.0236896  -0.04717022 -2.45976203  0.18859815
#   1.46675801 -0.91863467  0.96017787 -1.33658195 -0.49140026  0.95376627
#   1.15801661 -1.22738636 -0.24219794  0.57970444  0.69379885  0.4665998
#  -3.32852423  1.25469936  2.36576946 -0.19485014  0.40465771 -0.30090976
#  -2.34824868  0.45322397 -1.24823061  0.13047301 -0.42679724 -0.88499221
#   0.02015567 -1.06561379  1.7807058   0.08229268 -0.39778543  0.19513741
#  -0.65893354  1.02588846  0.50520796  0.16964895 -1.95805327  0.43451808
# ...

# %%
genders = ["male","female","male" , "male", "male"]
plt.hist(genders);
plt.show()

# %%
names= ["hamza" , "shahzad" , "john" , "nasir" , "nasir" , "john" , "john" , "shahzad"]
plt.hist(names)
# Out:
# (array([1., 0., 0., 2., 0., 0., 3., 0., 0., 2.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <a list of 10 Patch objects>)

# %%
import matplotlib.pyplot as plt
plt.bar([1, 2, 3 , 4], [3, 2, 5 , 8]);
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randn(1000)
y = np.random.randn(1000)
plt.scatter(x, y);
plt.show()

# %%
import matplotlib.pyplot as plt
weight = [70 , 80 , 56 , 85 , 105 ,45]
age  = [12 , 25,30,45,50,23]
plt.scatter(weight, age);
plt.show()

# %%
import matplotlib.pyplot as plt
y = [13, 11, 13, 12, 13, 10, 30, 12, 11, 13, 12, 12, 12, 11,12]
plt.plot(y);
plt.ylim(ymax=35);
plt.annotate('this spot must really\nmean something', xy=(6, 30), xytext=(8, 31.5), arrowprops=dict(facecolor='black',
shrink=0.05));
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

# %%
fig = plt.figure()
ax = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax1 = fig.add_subplot(211)
ax1.plot([1, 2, 3], [1, 2, 3]);
ax2 = fig.add_subplot(212)
ax2.plot([1, 2, 3], [3, 2, 1]);
plt.show()

# %%
import matplotlib.pyplot as plt
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
ax1.plot([1, 2, 3], [1, 2, 3]);
fig2 = plt.figure()
ax2 = fig2.add_subplot(111)
ax2.plot([1, 2, 3], [3, 2, 1]);
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0., np.e, 0.01)
y1 = np.exp(-x)
y2 = np.log(x)
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(x, y1);
ax1.set_ylabel('Y values for exp(-x)');
ax2 = ax1.twinx() # this is the important function
ax2.plot(x, y2, 'r');
ax2.set_xlim([0, np.e]);
ax2.set_ylabel('Y values for ln(x)');
ax2.set_xlabel('Same X for both exp(-x) and ln(x)');
plt.show()
# Out:
# /home/hamza/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """

# %%
import matplotlib.pyplot as plt 
import pandas as pd

climate_change = pd.read_csv("GlobalTemperatures.csv",parse_dates=["dt"], index_col="dt")
climate_change
# Out:
#             LandAverageTemperature  LandAverageTemperatureUncertainty  \
# dt
# 1750-01-01                   3.034                              3.574
# 1750-02-01                   3.083                              3.702
# 1750-03-01                   5.626                              3.076
# 1750-04-01                   8.490                              2.451
# 1750-05-01                  11.573                              2.072
# 1750-06-01                  12.937                              1.724
# 1750-07-01                  15.868                              1.911
# 1750-08-01                  14.750                              2.231
# 1750-09-01                  11.413                              2.637
# 1750-10-01                   6.367                              2.668
# 1750-11-01                     NaN                                NaN
# 1750-12-01                   2.772                              2.970
# ...

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

# Add the time-series for "relative_temp" to the plot
ax.plot(climate_change.index , climate_change["LandAverageTemperature"] )

# Set the x-axis label
ax.set_xlabel("Time")

# Set the y-axis label
ax.set_ylabel("Relative temperature (Celsius)")
# Out:
# Text(0, 0.5, 'Relative temperature (Celsius)')

# %%
fifteenth = climate_change["1750-01-01":"1750-12-01" ]
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

# Add the time-series for "relative_temp" to the plot
ax.plot(fifteenth.index , fifteenth["LandAverageTemperature"] )

# Set the x-axis label
ax.set_xlabel("Time")

# Set the y-axis label
ax.set_ylabel("Relative temperature (Celsius)")
# Out:
# Text(0, 0.5, 'Relative temperature (Celsius)')
