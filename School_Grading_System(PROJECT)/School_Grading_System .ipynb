# %%
#def cls():
#    print('\n'*50)
#cls()
from colorama import Fore, Back, Style
school_name='ABC SCHOOL'.center(110)
massage1='Student Result Card'.center(110)
#print('\n'*2)
print(Fore.BLACK,
     Back.BLUE,
     Style.BRIGHT,
     school_name,
     Style.RESET_ALL)
print('\n'*0)
print(Fore.BLACK,
     Back.BLUE,
     Style.BRIGHT,
     massage1,
     Style.RESET_ALL)
student_name=input('\n'"Enter the Student Name:"'\t\t\t\t')
sub1=float(input('\n'"Enter the marks of Subject 1:"'\t\t\t'))
sub2=float(input('\n'"Enter the marks of Subject 2:"'\t\t\t'))
sub3=float(input('\n'"Enter the marks of Subject 3:"'\t\t\t'))
sub4=float(input('\n'"Enter the marks of Subject 4:"'\t\t\t'))
sub5=float(input('\n'"Enter the marks of Subject 5:"'\t\t\t'))
sub6=float(input('\n'"Enter the marks of Subject 6:"'\t\t\t'))
print('\n')
if sub1<50.0:
    print(Fore.BLACK,
         Back.RED,
         Style.BRIGHT,
         f"You have FAILED in Suject 1 with obtain marks:{sub1}",
         Style.RESET_ALL)
if sub2<50.0:
    print(Fore.BLACK,
         Back.RED,
         Style.BRIGHT,
         f"You have FAILED in Suject 2 with obtain marks:{sub2}",
         Style.RESET_ALL)
if sub3<50.0:
    print(Fore.BLACK,
         Back.RED,
         Style.BRIGHT,
         f"You have FAILED in Suject 3 with obtain marks:{sub3}",
         Style.RESET_ALL)
if sub4<50.0:
    print(Fore.BLACK,
         Back.RED,
         Style.BRIGHT,
         f"You have FAILED in Suject 4 with obtain marks:{sub4}",
         Style.RESET_ALL)
if sub5<50.0:
    print(Fore.BLACK,
         Back.RED,
         Style.BRIGHT,
         f"You have FAILED in Suject 5 with obtain marks:{sub5}",
         Style.RESET_ALL)
if sub6<50.0:
    print(Fore.BLACK,
         Back.RED,
         Style.BRIGHT,
         f"You have FAILED in Suject 6 with obtain marks:{sub6}",
         Style.RESET_ALL)
if sub1>50.0 and sub2>50.0 and sub3>50.0 and sub4>50.0 and sub5>50.0 and sub6>50.0:
    print(Fore.BLACK,
         Back.GREEN,
         Style.BRIGHT,
         "You have Passed all the subjects".center(110),
         Style.RESET_ALL)
total_marks=sub1+sub2+sub3+sub4+sub5+sub6
print('\n'f"TOTAL MARKS: {total_marks}")
per=round((total_marks/600)*100,2)
print(f"PERCENTAGE: {per}")
if per>=90.0:
    print('\n',Fore.BLACK,
         Back.GREEN,
         Style.BRIGHT,
         "Grade: A+".center(110),
         Style.RESET_ALL)
elif 80.0<per<90.0:
    print('\n',Fore.BLACK,
         Back.LIGHTGREEN_EX,
         Style.BRIGHT,
         "Grade: A".center(110),
         Style.RESET_ALL)
elif 70.0<per<80.0:
    print('\n',Fore.BLACK,
         Back.YELLOW,
         Style.BRIGHT,
         "Grade: B".center(110),
         Style.RESET_ALL)
elif 60.0<per<70.0:
    print('\n',Fore.BLACK,
         Back.CYAN,
         Style.BRIGHT,
         "Grade: C".center(110),
         Style.RESET_ALL)
elif 50.0<per<60.0:
    print('\n',Fore.BLACK,
         Back.MAGENTA,
         Style.BRIGHT,
         "Grade: D".center(110),
         Style.RESET_ALL)
else:
    print('\n',
          Fore.BLACK,
         Back.RED,
         Style.BRIGHT,
         "FAILED".center(110),
         Style.RESET_ALL)
print('\n',
          Fore.BLACK,
         Back.BLUE,
         Style.BRIGHT,
         "Thank You".center(110),
         Style.RESET_ALL)
# Out:
#                                                      ABC SCHOOL
#
#                                                 Student Result Card
#
# Enter the Student Name:				FAIZAN
#
# Enter the marks of Subject 1:			78
#
# Enter the marks of Subject 2:			89
#
# Enter the marks of Subject 3:			45
#
# Enter the marks of Subject 4:			69
#
# Enter the marks of Subject 5:			82
#
# Enter the marks of Subject 6:			73
#
#
#    You have FAILED in Suject 3 with obtain marks:45.0
#
# TOTAL MARKS: 436.0
# PERCENTAGE: 72.67
#
#                                                        Grade: B
#
#                                                       Thank You

# %%
def creating_file (file_name):
    import datetime
    x = datetime.datetime.now()
    with open(file_name,"w") as f:
        f.write(f"FILE CREATED[{x}]")
    return
file_name=input("Enter File Name (with .txt)")
creating_file(file_name)
# Out:
# Enter File Name (with .txt)testing_file.txt

# %%
from colorama import Fore, Back, Style
def display_school_name (school_name):
    massage1=print(Fore.BLACK,
     Back.BLUE,
     Style.BRIGHT,
     school_name.center(110),
     Style.RESET_ALL)
    with open("file of student.txt", "w") as f:
        f.write(school_name.center(110))
        f.write('\n')
    return massage1
display_massage1=display_school_name('ABC SCHOOL')
# Out:
#                                                      ABC SCHOOL

# %%
def TitleOnPaper (title):
    massage2=print(Fore.BLACK,
     Back.BLUE,
     Style.BRIGHT,
     title.center(110),
     Style.RESET_ALL)
    with open("file of student.txt", "a") as f:
        f.write(title.center(110))
        f.write('\n')
    return massage2
display_massage2=TitleOnPaper('Student Result Card')
# Out:
#                                                 Student Result Card

# %%
def take_inputs ():
    student_name=input('\n'"Enter the Student Name:"'\t\t\t\t')
    with open("file of student.txt", "a") as f:
        f.write('\n'"Enter the Student Name:"'\t\t\t\t')
        f.write(student_name)
        f.write('\n')
    sub1=float(input('\n'"Enter the marks of Subject 1:"'\t\t\t'))
    with open("file of student.txt", "a") as f:
        f.write('\n'"Enter the marks of Subject 1:"'\t\t\t\t')
        f.write(str(sub1))
        f.write('\n')
    sub2=float(input('\n'"Enter the marks of Subject 2:"'\t\t\t'))
    with open("file of student.txt", "a") as f:
        f.write('\n'"Enter the marks of Subject 2:"'\t\t\t\t')
        f.write(str(sub2))
        f.write('\n')
    sub3=float(input('\n'"Enter the marks of Subject 3:"'\t\t\t'))
    with open("file of student.txt", "a") as f:
        f.write('\n'"Enter the marks of Subject 3:"'\t\t\t\t')
        f.write(str(sub3))
        f.write('\n')
    sub4=float(input('\n'"Enter the marks of Subject 4:"'\t\t\t'))
    with open("file of student.txt", "a") as f:
        f.write('\n'"Enter the marks of Subject 4:"'\t\t\t\t')
        f.write(str(sub4))
        f.write('\n')
    sub5=float(input('\n'"Enter the marks of Subject 5:"'\t\t\t'))
    with open("file of student.txt", "a") as f:
        f.write('\n'"Enter the marks of Subject 5:"'\t\t\t\t')
        f.write(str(sub5))
        f.write('\n')
    sub6=float(input('\n'"Enter the marks of Subject 6:"'\t\t\t'))
    with open("file of student.txt", "a") as f:
        f.write('\n'"Enter the marks of Subject 6:"'\t\t\t\t')
        f.write(str(sub6))
        f.write('\n')
    print('\n')
    return sub1,sub2,sub3,sub4,sub5,sub6

sub1,sub2,sub3,sub4,sub5,sub6=take_inputs()
# Out:
# Enter the Student Name:				FAIZAN QURESHI
#
# Enter the marks of Subject 1:			78
#
# Enter the marks of Subject 2:			45
#
# Enter the marks of Subject 3:			96
#
# Enter the marks of Subject 4:			36
#
# Enter the marks of Subject 5:			69
#
# Enter the marks of Subject 6:			63

# %%
def display_subj_massage (sub1,sub2,sub3,sub4,sub5,sub6):
    if sub1<50.0:
        print(Fore.BLACK,
         Back.RED,
         Style.BRIGHT,
         f"You have FAILED in Suject 1 with obtain marks:{sub1}",
         Style.RESET_ALL)
        with open("file of student.txt", "a") as f:
            f.write('\n'f"You have FAILED in Suject 1 with obtain marks:{sub1}")
            f.write('\n')
    if sub2<50.0:
        print(Fore.BLACK,
         Back.RED,
         Style.BRIGHT,
         f"You have FAILED in Suject 2 with obtain marks:{sub2}",
         Style.RESET_ALL)
        with open("file of student.txt", "a") as f:
            f.write('\n'f"You have FAILED in Suject 2 with obtain marks:{sub2}")
            f.write('\n')
    if sub3<50.0:
        print(Fore.BLACK,
         Back.RED,
         Style.BRIGHT,
         f"You have FAILED in Suject 3 with obtain marks:{sub3}",
         Style.RESET_ALL)
        with open("file of student.txt", "a") as f:
            f.write('\n'f"You have FAILED in Suject 3 with obtain marks:{sub3}")
            f.write('\n')
    if sub4<50.0:
        print(Fore.BLACK,
         Back.RED,
         Style.BRIGHT,
         f"You have FAILED in Suject 4 with obtain marks:{sub4}",
         Style.RESET_ALL)
        with open("file of student.txt", "a") as f:
            f.write('\n'f"You have FAILED in Suject 4 with obtain marks:{sub4}")
            f.write('\n')
    if sub5<50.0:
        print(Fore.BLACK,
         Back.RED,
         Style.BRIGHT,
         f"You have FAILED in Suject 5 with obtain marks:{sub5}",
         Style.RESET_ALL)
        with open("file of student.txt", "a") as f:
            f.write('\n'f"You have FAILED in Suject 5 with obtain marks:{sub5}")
            f.write('\n')
    if sub6<50.0:
        print(Fore.BLACK,
         Back.RED,
         Style.BRIGHT,
         f"You have FAILED in Suject 6 with obtain marks:{sub6}",
         Style.RESET_ALL)
        with open("file of student.txt", "a") as f:
            f.write('\n'f"You have FAILED in Suject 6 with obtain marks:{sub6}")
            f.write('\n')
    if sub1>50.0 and sub2>50.0 and sub3>50.0 and sub4>50.0 and sub5>50.0 and sub6>50.0:
        print(Fore.BLACK,
         Back.GREEN,
         Style.BRIGHT,
         "You have Passed all the subjects".center(110),
         Style.RESET_ALL)
        with open("file of student.txt", "a") as f:
            f.write('\n'"You have Passed all the subjects")
            f.write('\n')
    return

display_subj_massage(sub1,sub2,sub3,sub4,sub5,sub6)
# Out:
#    You have FAILED in Suject 2 with obtain marks:45.0
#    You have FAILED in Suject 4 with obtain marks:36.0

# %%
def calculations (sub1,sub2,sub3,sub4,sub5,sub6):
    total_marks=sub1+sub2+sub3+sub4+sub5+sub6
    print('\n'f"TOTAL MARKS: {total_marks}")
    with open("file of student.txt", "a") as f:
        f.write('\n'f"TOTAL MARKS: {total_marks}"'\n')
    per=round((total_marks/600)*100,2)
    print(f"PERCENTAGE: {per}")
    with open("file of student.txt", "a") as f:
        f.write(f"PERCENTAGE: {per}"'\n')
    return total_marks,per
total_marks,per=calculations(sub1,sub2,sub3,sub4,sub5,sub6)
# Out:
# TOTAL MARKS: 387.0
# PERCENTAGE: 64.5

# %%
def grading ():
    if per>=90.0:
        print('\n',Fore.BLACK,
         Back.GREEN,
         Style.BRIGHT,
         "Grade: A+".center(110),
         Style.RESET_ALL)
        with open("file of student.txt", "a") as f:
            f.write("Grade: A+")
    elif 80.0<per<90.0:
        print('\n',Fore.BLACK,
         Back.LIGHTGREEN_EX,
         Style.BRIGHT,
         "Grade: A".center(110),
         Style.RESET_ALL)
        with open("file of student.txt", "a") as f:
            f.write("Grade: A")
    elif 70.0<per<80.0:
        print('\n',Fore.BLACK,
         Back.YELLOW,
         Style.BRIGHT,
         "Grade: B".center(110),
         Style.RESET_ALL)
        with open("file of student.txt", "a") as f:
            f.write("Grade: B")
    elif 60.0<per<70.0:
        print('\n',Fore.BLACK,
         Back.CYAN,
         Style.BRIGHT,
         "Grade: C".center(110),
         Style.RESET_ALL)
        with open("file of student.txt", "a") as f:
            f.write("Grade: C")
    elif 50.0<per<60.0:
        print('\n',Fore.BLACK,
         Back.MAGENTA,
         Style.BRIGHT,
         "Grade: D".center(110),
         Style.RESET_ALL)
        with open("file of student.txt", "a") as f:
            f.write("Grade: D")
    else:
        print('\n',
          Fore.BLACK,
         Back.RED,
         Style.BRIGHT,
         "FAILED".center(110),
         Style.RESET_ALL)
        with open("file of student.txt", "a") as f:
            f.write("FAILED")
    return

grading ()
# Out:
#                                                        Grade: C
