# %%
import numpy as np
import pandas as pd
from pandas import DataFrame,Series

# %%
data=pd.read_csv('BlackFriday.csv')

# %%
data
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# ...

# %%
data.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
len(data.columns)
# Out:
# 12

# %%
data.count(axis='columns')
# Out:
# 0         10
# 1         12
# 2         10
# 3         11
# 4         10
# 5         11
# 6         12
# 7         11
# 8         11
# 9         10
# 10        11
# 11        10
# 12        10
# 13        12
# 14        12
# 15        11
# 16        12
# 17        11
# 18        12
# 19        12
# 20        11
# 21        10
# 22        10
# 23        10
# 24        12
# 25        11
# 26        10
# 27        11
# 28        12
# 29        12
#           ..
# 537547    12
# 537548    10
# 537549    12
# 537550    10
# 537551    12
# 537552    11
# 537553    11
# 537554    11
# 537555    11
# 537556    11
# 537557    10
# 537558    11
# 537559    11
# 537560    11
# 537561    11
# 537562    12
# 537563    10
# 537564    11
# 537565    10
# 537566    10
# 537567    11
# 537568    10
# 537569    11
# 537570    11
# 537571    12
# 537572    11
# 537573    12
# 537574    11
# 537575    10
# 537576    11
# Length: 537577, dtype: int64

# %%
data.index
# Out:
# RangeIndex(start=0, stop=537577, step=1)

# %%
data.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 537572                          1               0                   1
# 537573                          1               0                   1
# 537574                          1               0                   8
# 537575                          1               0                   5
# 537576                          1               0                   5
#
#         Product_Category_2  Product_Category_3  Purchase
# 537572                 2.0                 NaN     11664
# ...

# %%
data.tail(3)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 537574                          1               0                   8
# 537575                          1               0                   5
# 537576                          1               0                   5
#
#         Product_Category_2  Product_Category_3  Purchase
# 537574                15.0                 NaN      8043
# 537575                 NaN                 NaN      7172
# 537576                 8.0                 NaN      6875

# %%
data.tail(10)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 537567  1004736  P00157542      M  18-25          20             A
# 537568  1004736  P00250642      M  18-25          20             A
# 537569  1004736  P00023142      M  18-25          20             A
# 537570  1004736  P00162442      M  18-25          20             A
# 537571  1004737  P00221442      M  36-45          16             C
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 537567                          1               1                   8
# 537568                          1               1                  11
# ...

# %%
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
data.head(3)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422

# %%
data.head(8)
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000001  P00069042      F   0-17          10             A
# 1  1000001  P00248942      F   0-17          10             A
# 2  1000001  P00087842      F   0-17          10             A
# 3  1000001  P00085442      F   0-17          10             A
# 4  1000002  P00285442      M    55+          16             C
# 5  1000003  P00193542      M  26-35          15             A
# 6  1000004  P00184942      M  46-50           7             B
# 7  1000004  P00346142      M  46-50           7             B
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
# ...

# %%
#groupby()
#--> it will output the result on the basis of a certain column
data.groupby(['Product_ID']).count()
# Out:
#             User_ID  Gender   Age  Occupation  City_Category  \
# Product_ID
# P00000142      1130    1130  1130        1130           1130
# P00000242       371     371   371         371            371
# P00000342       238     238   238         238            238
# P00000442        92      92    92          92             92
# P00000542       146     146   146         146            146
# P00000642       512     512   512         512            512
# P00000742       238     238   238         238            238
# P00000842        36      36    36          36             36
# P00000942        54      54    54          54             54
# P00001042       494     494   494         494            494
# P00001142       572     572   572         572            572
# P00001242        99      99    99          99             99
# P00001342        61      61    61          61             61
# P00001442        83      83    83          83             83
# ...

# %%
data.groupby(['Marital_Status']).count()
# Out:
#                 User_ID  Product_ID  Gender     Age  Occupation  \
# Marital_Status
# 0                317817      317817  317817  317817      317817
# 1                219760      219760  219760  219760      219760
#
#                 City_Category  Stay_In_Current_City_Years  Product_Category_1  \
# Marital_Status
# 0                      317817                      317817              317817
# 1                      219760                      219760              219760
#
#                 Product_Category_2  Product_Category_3  Purchase
# Marital_Status
# 0                           220325               98202    317817
# 1                           150266               66076    219760

# %%
v1=sum(data.Marital_Status==1)
v1
# Out:
# 219760

# %%
v2=sum(data.Marital_Status==0)
v2
# Out:
# 317817

# %%
varTotal=v1+v2
varTotal
# Out:
# 537577

# %%
def DataInPercent (DataInNumber,Total):
    percent=(DataInNumber/Total)*100
    return percent

# %%
print("Married persons:",round(DataInPercent(v1,varTotal),2),"%")
# Out:
# Married persons: 40.88 %

# %%
print("UnMarried persons:",round(DataInPercent(v2,varTotal),2),"%")
# Out:
# UnMarried persons: 59.12 %

# %%
sum(data.Age<='18')
# Out:
# 14707

# %%
sum(data.Age>='18')
# Out:
# 522870

# %%
data[data.Age<'18']
# Out:
#         User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0       1000001  P00069042      F  0-17          10             A
# 1       1000001  P00248942      F  0-17          10             A
# 2       1000001  P00087842      F  0-17          10             A
# 3       1000001  P00085442      F  0-17          10             A
# 85      1000019  P00112542      M  0-17          10             A
# 86      1000019  P00339542      M  0-17          10             A
# 87      1000019  P00127842      M  0-17          10             A
# 88      1000019  P00125942      M  0-17          10             A
# 89      1000019  P00251342      M  0-17          10             A
# 90      1000019  P00249642      M  0-17          10             A
# 91      1000019  P00124842      M  0-17          10             A
# 92      1000019  P00250642      M  0-17          10             A
# 93      1000019  P00058142      M  0-17          10             A
# ...

# %%
data[data.Age>'18'].count()
# Out:
# User_ID                       522870
# Product_ID                    522870
# Gender                        522870
# Age                           522870
# Occupation                    522870
# City_Category                 522870
# Stay_In_Current_City_Years    522870
# Marital_Status                522870
# Product_Category_1            522870
# Product_Category_2            360125
# Product_Category_3            159489
# Purchase                      522870
# dtype: int64

# %%
data[(data.Age<'18') & (data.City_Category=='A')]
# Out:
#         User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0       1000001  P00069042      F  0-17          10             A
# 1       1000001  P00248942      F  0-17          10             A
# 2       1000001  P00087842      F  0-17          10             A
# 3       1000001  P00085442      F  0-17          10             A
# 85      1000019  P00112542      M  0-17          10             A
# 86      1000019  P00339542      M  0-17          10             A
# 87      1000019  P00127842      M  0-17          10             A
# 88      1000019  P00125942      M  0-17          10             A
# 89      1000019  P00251342      M  0-17          10             A
# 90      1000019  P00249642      M  0-17          10             A
# 91      1000019  P00124842      M  0-17          10             A
# 92      1000019  P00250642      M  0-17          10             A
# 93      1000019  P00058142      M  0-17          10             A
# ...

# %%
data[(data.Age<'18') & (data.City_Category=='A') & (data.Gender=='M')]
# Out:
#         User_ID Product_ID Gender   Age  Occupation City_Category  \
# 85      1000019  P00112542      M  0-17          10             A
# 86      1000019  P00339542      M  0-17          10             A
# 87      1000019  P00127842      M  0-17          10             A
# 88      1000019  P00125942      M  0-17          10             A
# 89      1000019  P00251342      M  0-17          10             A
# 90      1000019  P00249642      M  0-17          10             A
# 91      1000019  P00124842      M  0-17          10             A
# 92      1000019  P00250642      M  0-17          10             A
# 93      1000019  P00058142      M  0-17          10             A
# 94      1000019  P00117442      M  0-17          10             A
# 95      1000019  P00251642      M  0-17          10             A
# 96      1000019  P00244842      M  0-17          10             A
# 4526    1000737  P00202242      M  0-17          19             A
# ...

# %%
round(DataInPercent(sum(data.Age<'18')+sum(data.City_Category=='A')+sum(data.Gender=='M'),varTotal),2)
# Out:
# 105.05

# %%
t1=sum(data.Age<'18')
t1
# Out:
# 14707

# %%
t2=sum(data.City_Category=='A')
t2
# Out:
# 144638

# %%
t3=sum(data.Gender=='M')
t3
# Out:
# 405380

# %%
t_total=t1+t2+t3
t_total
# Out:
# 564725

# %%
varTotal
# Out:
# 537577

# %%
DataInPercent(t_total,varTotal)
# Out:
# 105.05006724618056

# %%
data[data.Marital_Status==1]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# 13      1000005  P00145042      M  26-35          20             A
# 18      1000007  P00036842      M  36-45           1             B
# 19      1000008  P00249542      M  26-35          12             C
# 20      1000008  P00220442      M  26-35          12             C
# 21      1000008  P00156442      M  26-35          12             C
# 22      1000008  P00213742      M  26-35          12             C
# ...

# %%
data[data.Marital_Status==0]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 14      1000006  P00231342      F  51-55           9             A
# 15      1000006  P00190242      F  51-55           9             A
# 16      1000006   P0096642      F  51-55           9             A
# 17      1000006  P00058442      F  51-55           9             A
# 25      1000009  P00135742      M  26-35          17             C
# 26      1000009  P00039942      M  26-35          17             C
# 27      1000009  P00161442      M  26-35          17             C
# ...

# %%
print("Male Percentage:",round(DataInPercent(sum(data.Gender=='M'),537577)),"%")
# Out:
# Male Percentage: 75 %

# %%
print("Female Percentage:",round(DataInPercent(sum(data.Gender=='F'),537577)),"%")
# Out:
# Female Percentage: 25 %

# %%
data.iloc[5]
# Out:
# User_ID                         1000003
# Product_ID                    P00193542
# Gender                                M
# Age                               26-35
# Occupation                           15
# City_Category                         A
# Stay_In_Current_City_Years            3
# Marital_Status                        0
# Product_Category_1                    1
# Product_Category_2                    2
# Product_Category_3                  NaN
# Purchase                          15227
# Name: 5, dtype: object

# %%
data.loc[5]
# Out:
# User_ID                         1000003
# Product_ID                    P00193542
# Gender                                M
# Age                               26-35
# Occupation                           15
# City_Category                         A
# Stay_In_Current_City_Years            3
# Marital_Status                        0
# Product_Category_1                    1
# Product_Category_2                    2
# Product_Category_3                  NaN
# Purchase                          15227
# Name: 5, dtype: object

# %%
data.loc[6]
# Out:
# User_ID                         1000004
# Product_ID                    P00184942
# Gender                                M
# Age                               46-50
# Occupation                            7
# City_Category                         B
# Stay_In_Current_City_Years            2
# Marital_Status                        1
# Product_Category_1                    1
# Product_Category_2                    8
# Product_Category_3                   17
# Purchase                          19215
# Name: 6, dtype: object

# %%
data.groupby(['Gender','Age']).count()
# Out:
#               User_ID  Product_ID  Occupation  City_Category  \
# Gender Age
# F      0-17      4953        4953        4953           4953
#        18-25    24057       24057       24057          24057
#        26-35    49348       49348       49348          49348
#        36-45    26420       26420       26420          26420
#        46-50    12856       12856       12856          12856
#        51-55     9634        9634        9634           9634
#        55+       4929        4929        4929           4929
# M      0-17      9754        9754        9754           9754
#        18-25    73577       73577       73577          73577
#        26-35   165342      165342      165342         165342
#        36-45    81079       81079       81079          81079
#        46-50    31670       31670       31670          31670
#        51-55    27984       27984       27984          27984
#        55+      15974       15974       15974          15974
#
# ...

# %%
data.groupby(['Marital_Status','Age']).count()
# Out:
#                       User_ID  Product_ID  Gender  Occupation  City_Category  \
# Marital_Status Age
# 0              0-17     14707       14707   14707       14707          14707
#                18-25    76993       76993   76993       76993          76993
#                26-35   130524      130524  130524      130524         130524
#                36-45    64992       64992   64992       64992          64992
#                46-50    12332       12332   12332       12332          12332
#                51-55    10639       10639   10639       10639          10639
#                55+       7630        7630    7630        7630           7630
# 1              18-25    20641       20641   20641       20641          20641
#                26-35    84166       84166   84166       84166          84166
#                36-45    42507       42507   42507       42507          42507
#                46-50    32194       32194   32194       32194          32194
# ...
